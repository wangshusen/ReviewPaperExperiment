# %%
import numpy
import sys
sys.path.append('../../main/regression/')
import scipy.io

#### To Be Specified
filename = '../../resource/clusteringdata/mnist.scale.mat' 

# load data
dataDict = scipy.io.loadmat(filename)
matX = dataDict['X'].toarray()
vecY = dataDict['y']
type(matX)
# Out:
# numpy.ndarray

# %%
print(vecY)
# Out:
# [[5]
#  [0]
#  [4]
#  ...,
#  [5]
#  [6]
#  [8]]

# %%
import time

import numpy
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
n_samples = 200
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.03)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = numpy.random.rand(n_samples, 2), None
noisy_s_curve = datasets.make_s_curve(n_samples=n_samples, noise=0.05)

# %%
X = noisy_circles[0]
y = noisy_circles[1]

# %%
colors = numpy.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = numpy.hstack([colors] * 20)

# %%
plt.scatter(X[:, 0], X[:, 1], color=colors[y].tolist(), s=10)
plt.show()

# %%
import sys
sys.path.append('../../main/kernel/')
import kernelFun

# %%
matK = kernelFun.rbf(X, X, 0.5)
matU, vecS, _ = numpy.linalg.svd(matK, full_matrices=False)
k = 2
matXkpca = matU[:, 0:k] * numpy.sqrt(vecS[0:k]).reshape(1, k)

plt.scatter(matXkpca[:, 0], matXkpca[:, 1], color=colors[y].tolist(), s=10)
plt.show()
# Out:
# (200, 2)

# %%
idx1 = (y==1)
idx0 = (y==0)
idx = numpy.array(range(200))
X1 = X[idx1, :]
X0 = X[idx0, :]
y1 = y[idx1]
y0 = y[idx0]
Xnew = numpy.concatenate((X1, X0))
ynew = numpy.concatenate((y1, y0))
print(Xnew.shape)
# Out:
# (100,)

# %%
from mpl_toolkits.mplot3d import Axes3D


Axes3D

X = noisy_s_curve[0]
y = noisy_s_curve[1]


fig = plt.figure(figsize=(25, 15))
plt.suptitle("Manifold Learning with %i points, %i neighbors"
             % (1000, 1), fontsize=14)
ax = fig.add_subplot(251, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.Spectral)
ax.view_init(4, -72)
y[1:20]
# Out:
# array([ 1.72073981, -1.56904199,  3.1173751 ,  2.82978917, -3.95631477,
#         1.6341339 ,  0.74213814, -4.36185879, -2.67224303,  3.20768279,
#        -3.04126799, -2.71226655,  1.56175797, -2.26531982, -0.92865002,
#        -1.56146492,  3.5011186 ,  0.10710683,  0.72358668])

# %%
matK = kernelFun.rbf(X, X, 0.15)
matU, vecS, _ = numpy.linalg.svd(matK, full_matrices=False)
k = 10
matXkpca = matU[:, 0:k] * numpy.sqrt(vecS[0:k]).reshape(1, k)

plt.scatter(matXkpca[:, 0], matXkpca[:, 1], c=y*3, s=10)
plt.show()

# %%
fig = plt.figure(figsize=(25, 15))
plt.suptitle("Manifold Learning with %i points, %i neighbors"
             % (1000, 1), fontsize=14)
ax = fig.add_subplot(251, projection='3d')
ax.scatter(matXkpca[:, 0], matXkpca[:, 1], matXkpca[:, 2], c=y, cmap=plt.cm.Spectral)
ax.view_init(4, -72)

# %%
matA = numpy.random.rand(100, 100)
matA = (matA + matA.T)/2



print(matA)
# Out:
# [[ 0.85805464  0.96476813  0.15558199 ...,  0.47438668  0.4303025
#    0.45027704]
#  [ 0.96476813  0.46211865  0.51717834 ...,  0.48559564  0.32118374
#    0.70797366]
#  [ 0.15558199  0.51717834  0.43952938 ...,  0.5526016   0.57749772
#    0.4778061 ]
#  ...,
#  [ 0.47438668  0.48559564  0.5526016  ...,  0.56039496  0.02000032
#    0.17239065]
#  [ 0.4303025   0.32118374  0.57749772 ...,  0.02000032  0.83519851
#    0.66861057]
#  [ 0.45027704  0.70797366  0.4778061  ...,  0.17239065  0.66861057
#    0.97568226]]
